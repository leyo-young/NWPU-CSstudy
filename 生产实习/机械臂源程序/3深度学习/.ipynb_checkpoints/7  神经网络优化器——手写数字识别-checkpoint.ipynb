# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision.datasets as dsets
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
from tqdm import tqdm
import numpy as np
# %matplotlib inline

# %%
# 定义超参数 
image_size = 28  #图像的总尺寸28*28
num_classes = 10  #标签的种类数
num_epochs = 20  #训练的总循环周期
batch_size = 64  #一个撮（批次）的大小，64张图片
# 加载MINIST数据，如果没有下载过，就会在当前路径下新建/data子目录，并把文件存放其中
# MNIST数据是属于torchvision包自带的数据，所以可以直接调用。
# 在调用自己的数据的时候，我们可以用torchvision.datasets.ImageFolder或者torch.utils.data.TensorDataset来加载
train_dataset = dsets.MNIST(root='/home/retoo/Desktop/实验/数据集/3.深度学习/7data/MNIST', download=True, #文件存放路径
                            train=True,   #提取训练集
                            transform=transforms.ToTensor()) 
#当找不到文件的时候，自动下载 ；将图像转化为Tensor，在加载数据的时候，就可以对图像做预处理
# 加载测试数据集
test_dataset = dsets.MNIST(root='/home/retoo/Desktop/实验/数据集/3.深度学习/7data/MNIST', download=True,
                           train=False, 
                           transform=transforms.ToTensor())
# 训练数据集的加载器，自动将数据分割成batch，顺序随机打乱
train_loader = torch.utils.data.DataLoader(dataset=train_dataset, 
                                           batch_size=batch_size, 
                                           shuffle=True)
'''我们希望将测试数据分成两部分，一部分作为校验数据，一部分作为测试数据。
校验数据用于检测模型是否过拟合，并调整参数，测试数据检验整个模型的工作'''
# 首先，我们定义下标数组indices，它相当于对所有test_dataset中数据的编码
# 然后定义下标indices_val来表示校验集数据的那些下标，indices_test表示测试集的下标
indices = range(len(test_dataset))
indices_val = indices[:5000]
indices_test = indices[5000:]
# 根据这些下标，构造两个数据集的SubsetRandomSampler采样器，它会对下标进行采样
sampler_val = torch.utils.data.sampler.SubsetRandomSampler(indices_val)
sampler_test = torch.utils.data.sampler.SubsetRandomSampler(indices_test)
# 根据两个采样器来定义加载器，注意将sampler_val和sampler_test分别赋值给了validation_loader和test_loader
validation_loader = torch.utils.data.DataLoader(dataset =test_dataset,
                                                batch_size = batch_size,
                                                sampler = sampler_val
                                               )
test_loader = torch.utils.data.DataLoader(dataset=test_dataset, 
                                          batch_size=batch_size, 
                                          sampler = sampler_test
                                         )

# %%
#随便从数据集中读入一张图片，并绘制出来
idx = 1000
#dataset支持下标索引，其中提取出来的每一个元素为features，target格式，即属性和标签。[0]表示索引features
muteimg = train_dataset[idx][0].numpy()
#由于一般的图像包含rgb三个通道，而MINST数据集的图像都是灰度的，只有一个通道。因此，我们忽略通道，把图像看作一个灰度矩阵。
#用imshow画图，会将灰度矩阵自动展现为彩色，不同灰度对应不同颜色：从黄到紫
plt.imshow(muteimg[0,...])
print('标签是：',train_dataset[idx][1])
# Out:
# 标签是： 0

# %%
#定义卷积神经网络：4和8为人为指定的两个卷积层的厚度（feature map的数量）
depth = [4, 8]
class ConvNet(nn.Module):
    def __init__(self):
        # 该函数在创建一个ConvNet对象的时候，即调用如下语句：net=ConvNet()，就会被调用
        # 首先调用父类相应的构造函数
        super(ConvNet, self).__init__()
        # 其次构造ConvNet需要用到的各个神经模块。
        '''注意，定义组件并没有真正搭建这些组件，只是把基本建筑砖块先找好'''
        self.conv1 = nn.Conv2d(1, 4, 5, padding = 2) #定义一个卷积层，输入通道为1，输出通道为4，窗口大小为5，padding为2
        self.pool = nn.MaxPool2d(2, 2) #定义一个Pooling层，一个窗口为2*2的pooling运算
        self.conv2 = nn.Conv2d(depth[0], depth[1], 5, padding = 2) #第二层卷积，输入通道为depth[0], 
                                                                   #输出通道为depth[1]，窗口为5，padding为2
        self.fc1 = nn.Linear(image_size // 4 * image_size // 4 * depth[1] , 512) 
                                                            #一个线性连接层，输入尺寸为最后一层立方体的平铺，输出层512个节点
        self.fc2 = nn.Linear(512, num_classes) #最后一层线性分类单元，输入为512，输出为要做分类的类别数
    def forward(self, x):
        #该函数完成神经网络真正的前向运算，我们会在这里把各个组件进行实际的拼装
        #x的尺寸：(batch_size, image_channels, image_width, image_height)
        x = F.relu(self.conv1(x))  #第一层卷积，激活函数用ReLu，为了防止过拟合
        #x的尺寸：(batch_size, num_filters, image_width, image_height)
        x = self.pool(x) #第二层pooling，将图片变小
        #x的尺寸：(batch_size, depth[0], image_width/2, image_height/2)
        x = F.relu(self.conv2(x)) #第三层又是卷积，窗口为5，输入输出通道分别为depth[0]=4, depth[1]=8
        #x的尺寸：(batch_size, depth[1], image_width/2, image_height/2)
        x = self.pool(x) #第四层pooling，将图片缩小到原大小的1/4
        #x的尺寸：(batch_size, depth[1], image_width/4, image_height/4)
        # 将立体的特征图Tensor，压成一个一维的向量
        # view这个函数可以将一个tensor按指定的方式重新排布。
        # 下面这个命令就是要让x按照batch_size * (image_size//4)^2*depth[1]的方式来排布向量
        x = x.view(-1, image_size // 4 * image_size // 4 * depth[1])
        #x的尺寸：(batch_size, depth[1]*image_width/4*image_height/4)
        x = F.relu(self.fc1(x)) #第五层为全链接，ReLu激活函数
        #x的尺寸：(batch_size, 512)
        x = F.dropout(x, training=self.training) #以默认为0.5的概率对这一层进行dropout操作，为了防止过拟合
        x = self.fc2(x) #全链接
        #x的尺寸：(batch_size, num_classes)
        x = F.log_softmax(x, dim = 0) #输出层为log_softmax，即概率对数值log(p(x))。采用log_softmax可以使得后面的交叉熵计算更快
        return x
    def retrieve_features(self, x):
        #该函数专门用于提取卷积神经网络的特征图的功能，返回feature_map1, feature_map2为前两层卷积层的特征图
        feature_map1 = F.relu(self.conv1(x)) #完成第一层卷积
        x = self.pool(feature_map1)  # 完成第一层pooling
        feature_map2 = F.relu(self.conv2(x)) #第二层卷积，两层特征图都存储到了feature_map1, feature_map2中
        return (feature_map1, feature_map2)

# %%
net = ConvNet()  # 新建一个卷积神经网络的实例，此时ConvNet的__init__函数就会被自动调用

criterion = nn.CrossEntropyLoss()  # Loss函数的定义，交叉熵
# optimizer = optim.Adam(net.parameters(), lr=0.001,betas=(0.9, 0.99)) #定义优化器
# optimizer = optim.SGD(net.parameters(),lr=0.001, momentum=0.9)
optimzier = torch.optim.RMSprop(net.parameters(), lr=0.001, alpha=0.9)
# optimzier= torch.optim.SGD(net_SGD.parameters(), lr=0.001)
record = []  # 记录准确率等数值的容器
weights = []  # 每若干步就记录一次卷积核

def rightness(output, target):
    pred=output.data.max(dim=1,keepdim=True)[1]
    return  pred.eq(target.data.view_as(pred)).cpu().sum(),len(target)

# 开始训练循环
for epoch in range(num_epochs):

    train_rights = []  # 记录训练数据集准确率的容器

    ''' 下面的enumerate是构造一个枚举器的作用。就是我们在对train_loader做循环迭代的时候，enumerate会自动吐出一个数字指示我们循环了几次
     这个数字就被记录在了batch_idx之中，它就等于0，1.txt，2，……
     train_loader每迭代一次，就会吐出来一对数据data和target，分别对应着一个batch中的手写数字图，以及对应的标签。'''

    for batch_idx, (data, target) in enumerate(train_loader):  # 针对容器中的每一个批进行循环
        data, target = data.clone().requires_grad_(True), target.clone().detach()
        # data为一批图像，target为一批标签
        #x.data（x.detach()） 返回和 x 的相同数据 tensor, 这个新的tensor和原来的tensor（即x）是共用数据的，一者改变，另一者也会跟着改变，且require s_grad = False
        #不同点： x.data 不能被 autograd 追踪求微分，即使被改了也能错误求导，而x.detach()则不行
        net.train()  # 给网络模型做标记，标志说模型正在训练集上训练，
        # 这种区分主要是为了打开关闭net的training标志，从而决定是否运行dropout

        output = net(data)  # 神经网络完成一次前馈的计算过程，得到预测输出output
        loss = criterion(output, target)  # 将output与标签target比较，计算误差
        optimzier.zero_grad()  # 清空梯度
        loss.backward()  # 反向传播
        optimzier.step()  # 一步随机梯度下降算法
        right = rightness(output, target)  # 计算准确率所需数值，返回数值为（正确样例数，总样本数）
        train_rights.append(right)  # 将计算结果装到列表容器train_rights中

        if batch_idx % 100 == 0:  # 每间隔100个batch执行一次打印等操作

            net.eval()  # 给网络模型做标记，标志说模型在训练集上训练
            val_rights = []  # 记录校验数据集准确率的容器

            '''开始在校验数据集上做循环，计算校验集上面的准确度'''
            for (data, target) in validation_loader:
                data, target = data.clone().requires_grad_(True), target.clone().detach()
                output = net(data)  # 完成一次前馈计算过程，得到目前训练得到的模型net在校验数据集上的表现
                right = rightness(output, target)  # 计算准确率所需数值，返回正确的数值为（正确样例数，总样本数）
                val_rights.append(right)

            # 分别计算在目前已经计算过的测试数据集，以及全部校验集上模型的表现：分类准确率
            # train_r为一个二元组，分别记录目前已经经历过的所有训练集中分类正确的数量和该集合中总的样本数，
            # train_r[0]/train_r[1.txt]就是训练集的分类准确度，同样，val_r[0]/val_r[1.txt]就是校验集上的分类准确度
            train_r = (sum([tup[0] for tup in train_rights]), sum([tup[1] for tup in train_rights]))
            # val_r为一个二元组，分别记录校验集中分类正确的数量和该集合中总的样本数
            val_r = (sum([tup[0] for tup in val_rights]), sum([tup[1] for tup in val_rights]))
            # 打印准确率等数值，其中正确率为本训练周期Epoch开始后到目前撮的正确率的平均值
            print(val_r)
            print('训练周期: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}\t训练正确率: {:.2f}%\t校验正确率: {:.2f}%'.format(
                epoch, batch_idx * batch_size, len(train_loader.dataset),
                       100. * batch_idx / len(train_loader),
                loss.data,
                       100. * train_r[0].numpy() / train_r[1],
                       100. * val_r[0].numpy() / val_r[1]))

            # 将准确率和权重等数值加载到容器中，以方便后续处理
            record.append((100 - 100. * train_r[0] / train_r[1], 100 - 100. * val_r[0] / val_r[1]))
            # weights记录了训练周期中所有卷积核的演化过程。net.conv1.weight就提取出了第一层卷积核的权重
            # clone的意思就是将weight.data中的数据做一个拷贝放到列表中，否则当weight.data变化的时候，列表中的每一项数值也会联动
            '''这里使用clone这个函数很重要'''
            weights.append([net.conv1.weight.data.clone(), net.conv1.bias.data.clone(),
                            net.conv2.weight.data.clone(), net.conv2.bias.data.clone()])


# 绘制实验结果，打印测试集上的准确度
plt.plot([i[0] for i in record],label='Train')
plt.plot([i[1] for i in record],label='Validation')
# right_rate
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Error Rate')
# Out:
# (tensor(2242), 5000)
# 训练周期: 0 [0/60000 (0%)]	Loss: 2.294060	训练正确率: 14.06%	校验正确率: 44.84%
# (tensor(4325), 5000)
# 训练周期: 0 [6400/60000 (11%)]	Loss: 0.497465	训练正确率: 71.18%	校验正确率: 86.50%
# (tensor(4524), 5000)
# 训练周期: 0 [12800/60000 (21%)]	Loss: 0.377025	训练正确率: 78.73%	校验正确率: 90.48%
# (tensor(4599), 5000)
# 训练周期: 0 [19200/60000 (32%)]	Loss: 0.170903	训练正确率: 82.57%	校验正确率: 91.98%
# (tensor(4652), 5000)
# 训练周期: 0 [25600/60000 (43%)]	Loss: 0.225853	训练正确率: 85.04%	校验正确率: 93.04%
# (tensor(4716), 5000)
# 训练周期: 0 [32000/60000 (53%)]	Loss: 0.247414	训练正确率: 86.75%	校验正确率: 94.32%
# (tensor(4751), 5000)
# 训练周期: 0 [38400/60000 (64%)]	Loss: 0.072635	训练正确率: 88.07%	校验正确率: 95.02%
# (tensor(4776), 5000)
# 训练周期: 0 [44800/60000 (75%)]	Loss: 0.198117	训练正确率: 89.04%	校验正确率: 95.52%
# (tensor(4809), 5000)
# 训练周期: 0 [51200/60000 (85%)]	Loss: 0.235604	训练正确率: 89.83%	校验正确率: 96.18%
# (tensor(4805), 5000)
# 训练周期: 0 [57600/60000 (96%)]	Loss: 0.213463	训练正确率: 90.50%	校验正确率: 96.10%
# (tensor(4823), 5000)
# 训练周期: 1 [0/60000 (0%)]	Loss: 0.046676	训练正确率: 98.44%	校验正确率: 96.46%
# (tensor(4844), 5000)
# 训练周期: 1 [6400/60000 (11%)]	Loss: 0.176916	训练正确率: 96.52%	校验正确率: 96.88%
# (tensor(4835), 5000)
# 训练周期: 1 [12800/60000 (21%)]	Loss: 0.122179	训练正确率: 96.62%	校验正确率: 96.70%
# (tensor(4852), 5000)
# 训练周期: 1 [19200/60000 (32%)]	Loss: 0.061701	训练正确率: 96.72%	校验正确率: 97.04%
# (tensor(4845), 5000)
# 训练周期: 1 [25600/60000 (43%)]	Loss: 0.141282	训练正确率: 96.77%	校验正确率: 96.90%
# (tensor(4843), 5000)
# 训练周期: 1 [32000/60000 (53%)]	Loss: 0.062968	训练正确率: 96.80%	校验正确率: 96.86%
# (tensor(4854), 5000)
# 训练周期: 1 [38400/60000 (64%)]	Loss: 0.101800	训练正确率: 96.81%	校验正确率: 97.08%
# (tensor(4851), 5000)
# 训练周期: 1 [44800/60000 (75%)]	Loss: 0.026084	训练正确率: 96.89%	校验正确率: 97.02%
# (tensor(4867), 5000)
# 训练周期: 1 [51200/60000 (85%)]	Loss: 0.014865	训练正确率: 96.86%	校验正确率: 97.34%
# (tensor(4843), 5000)
# 训练周期: 1 [57600/60000 (96%)]	Loss: 0.110938	训练正确率: 96.90%	校验正确率: 96.86%
# (tensor(4871), 5000)
# 训练周期: 2 [0/60000 (0%)]	Loss: 0.068136	训练正确率: 96.88%	校验正确率: 97.42%
# (tensor(4878), 5000)
# 训练周期: 2 [6400/60000 (11%)]	Loss: 0.014890	训练正确率: 97.83%	校验正确率: 97.56%
# (tensor(4867), 5000)
# 训练周期: 2 [12800/60000 (21%)]	Loss: 0.130540	训练正确率: 97.75%	校验正确率: 97.34%
# (tensor(4886), 5000)
# 训练周期: 2 [19200/60000 (32%)]	Loss: 0.035989	训练正确率: 97.70%	校验正确率: 97.72%
# (tensor(4880), 5000)
# 训练周期: 2 [25600/60000 (43%)]	Loss: 0.049335	训练正确率: 97.71%	校验正确率: 97.60%
# (tensor(4874), 5000)
# 训练周期: 2 [32000/60000 (53%)]	Loss: 0.008025	训练正确率: 97.72%	校验正确率: 97.48%
# (tensor(4862), 5000)
# 训练周期: 2 [38400/60000 (64%)]	Loss: 0.009399	训练正确率: 97.67%	校验正确率: 97.24%
# (tensor(4878), 5000)
# 训练周期: 2 [44800/60000 (75%)]	Loss: 0.188763	训练正确率: 97.67%	校验正确率: 97.56%
# (tensor(4879), 5000)
# 训练周期: 2 [51200/60000 (85%)]	Loss: 0.047495	训练正确率: 97.73%	校验正确率: 97.58%
# (tensor(4883), 5000)
# 训练周期: 2 [57600/60000 (96%)]	Loss: 0.039630	训练正确率: 97.76%	校验正确率: 97.66%
# (tensor(4876), 5000)
# 训练周期: 3 [0/60000 (0%)]	Loss: 0.008844	训练正确率: 100.00%	校验正确率: 97.52%
# (tensor(4876), 5000)
# 训练周期: 3 [6400/60000 (11%)]	Loss: 0.014625	训练正确率: 98.51%	校验正确率: 97.52%
# (tensor(4880), 5000)
# 训练周期: 3 [12800/60000 (21%)]	Loss: 0.070509	训练正确率: 98.12%	校验正确率: 97.60%
# (tensor(4886), 5000)
# 训练周期: 3 [19200/60000 (32%)]	Loss: 0.090319	训练正确率: 98.08%	校验正确率: 97.72%
# (tensor(4882), 5000)
# 训练周期: 3 [25600/60000 (43%)]	Loss: 0.081032	训练正确率: 98.04%	校验正确率: 97.64%
# (tensor(4879), 5000)
# 训练周期: 3 [32000/60000 (53%)]	Loss: 0.145709	训练正确率: 98.02%	校验正确率: 97.58%
# (tensor(4891), 5000)
# 训练周期: 3 [38400/60000 (64%)]	Loss: 0.009068	训练正确率: 97.99%	校验正确率: 97.82%
# (tensor(4879), 5000)
# 训练周期: 3 [44800/60000 (75%)]	Loss: 0.071446	训练正确率: 97.99%	校验正确率: 97.58%
# (tensor(4901), 5000)
# 训练周期: 3 [51200/60000 (85%)]	Loss: 0.033667	训练正确率: 98.01%	校验正确率: 98.02%
# (tensor(4876), 5000)
# 训练周期: 3 [57600/60000 (96%)]	Loss: 0.008212	训练正确率: 98.04%	校验正确率: 97.52%
# (tensor(4899), 5000)
# 训练周期: 4 [0/60000 (0%)]	Loss: 0.053729	训练正确率: 96.88%	校验正确率: 97.98%
# (tensor(4909), 5000)
# 训练周期: 4 [6400/60000 (11%)]	Loss: 0.030595	训练正确率: 98.41%	校验正确率: 98.18%
# (tensor(4898), 5000)
# 训练周期: 4 [12800/60000 (21%)]	Loss: 0.012689	训练正确率: 98.36%	校验正确率: 97.96%
# (tensor(4897), 5000)
# 训练周期: 4 [19200/60000 (32%)]	Loss: 0.092983	训练正确率: 98.32%	校验正确率: 97.94%
# (tensor(4900), 5000)
# 训练周期: 4 [25600/60000 (43%)]	Loss: 0.224540	训练正确率: 98.32%	校验正确率: 98.00%
# (tensor(4900), 5000)
# 训练周期: 4 [32000/60000 (53%)]	Loss: 0.041439	训练正确率: 98.33%	校验正确率: 98.00%
# (tensor(4906), 5000)
# 训练周期: 4 [38400/60000 (64%)]	Loss: 0.001091	训练正确率: 98.34%	校验正确率: 98.12%
# (tensor(4891), 5000)
# 训练周期: 4 [44800/60000 (75%)]	Loss: 0.023934	训练正确率: 98.29%	校验正确率: 97.82%
# (tensor(4903), 5000)
# 训练周期: 4 [51200/60000 (85%)]	Loss: 0.124159	训练正确率: 98.30%	校验正确率: 98.06%
# (tensor(4908), 5000)
# 训练周期: 4 [57600/60000 (96%)]	Loss: 0.001946	训练正确率: 98.31%	校验正确率: 98.16%
# (tensor(4890), 5000)
# 训练周期: 5 [0/60000 (0%)]	Loss: 0.060191	训练正确率: 98.44%	校验正确率: 97.80%
# (tensor(4892), 5000)
# 训练周期: 5 [6400/60000 (11%)]	Loss: 0.008721	训练正确率: 98.62%	校验正确率: 97.84%
# (tensor(4892), 5000)
# 训练周期: 5 [12800/60000 (21%)]	Loss: 0.018419	训练正确率: 98.60%	校验正确率: 97.84%
# (tensor(4892), 5000)
# 训练周期: 5 [19200/60000 (32%)]	Loss: 0.079224	训练正确率: 98.57%	校验正确率: 97.84%
# (tensor(4901), 5000)
# 训练周期: 5 [25600/60000 (43%)]	Loss: 0.155595	训练正确率: 98.48%	校验正确率: 98.02%
# (tensor(4896), 5000)
# 训练周期: 5 [32000/60000 (53%)]	Loss: 0.039588	训练正确率: 98.43%	校验正确率: 97.92%
# (tensor(4883), 5000)
# 训练周期: 5 [38400/60000 (64%)]	Loss: 0.007194	训练正确率: 98.42%	校验正确率: 97.66%
# (tensor(4900), 5000)
# 训练周期: 5 [44800/60000 (75%)]	Loss: 0.008720	训练正确率: 98.42%	校验正确率: 98.00%
# (tensor(4896), 5000)
# 训练周期: 5 [51200/60000 (85%)]	Loss: 0.026011	训练正确率: 98.42%	校验正确率: 97.92%
# (tensor(4898), 5000)
# 训练周期: 5 [57600/60000 (96%)]	Loss: 0.071752	训练正确率: 98.38%	校验正确率: 97.96%
# (tensor(4886), 5000)
# 训练周期: 6 [0/60000 (0%)]	Loss: 0.037775	训练正确率: 98.44%	校验正确率: 97.72%
# (tensor(4887), 5000)
# 训练周期: 6 [6400/60000 (11%)]	Loss: 0.013850	训练正确率: 98.67%	校验正确率: 97.74%
# (tensor(4883), 5000)
# 训练周期: 6 [12800/60000 (21%)]	Loss: 0.086923	训练正确率: 98.65%	校验正确率: 97.66%
# (tensor(4899), 5000)
# 训练周期: 6 [19200/60000 (32%)]	Loss: 0.022059	训练正确率: 98.54%	校验正确率: 97.98%
# (tensor(4897), 5000)
# 训练周期: 6 [25600/60000 (43%)]	Loss: 0.058158	训练正确率: 98.53%	校验正确率: 97.94%
# (tensor(4896), 5000)
# 训练周期: 6 [32000/60000 (53%)]	Loss: 0.057887	训练正确率: 98.53%	校验正确率: 97.92%
# (tensor(4903), 5000)
# 训练周期: 6 [38400/60000 (64%)]	Loss: 0.008684	训练正确率: 98.53%	校验正确率: 98.06%
# (tensor(4900), 5000)
# 训练周期: 6 [44800/60000 (75%)]	Loss: 0.043135	训练正确率: 98.51%	校验正确率: 98.00%
# (tensor(4897), 5000)
# 训练周期: 6 [51200/60000 (85%)]	Loss: 0.023599	训练正确率: 98.52%	校验正确率: 97.94%
# (tensor(4908), 5000)
# 训练周期: 6 [57600/60000 (96%)]	Loss: 0.013689	训练正确率: 98.50%	校验正确率: 98.16%
# (tensor(4906), 5000)
# 训练周期: 7 [0/60000 (0%)]	Loss: 0.030358	训练正确率: 100.00%	校验正确率: 98.12%
# (tensor(4908), 5000)
# 训练周期: 7 [6400/60000 (11%)]	Loss: 0.023181	训练正确率: 98.56%	校验正确率: 98.16%
# (tensor(4896), 5000)
# 训练周期: 7 [12800/60000 (21%)]	Loss: 0.068487	训练正确率: 98.60%	校验正确率: 97.92%
# (tensor(4911), 5000)
# 训练周期: 7 [19200/60000 (32%)]	Loss: 0.011298	训练正确率: 98.68%	校验正确率: 98.22%
# (tensor(4895), 5000)
# 训练周期: 7 [25600/60000 (43%)]	Loss: 0.021758	训练正确率: 98.66%	校验正确率: 97.90%
# (tensor(4894), 5000)
# 训练周期: 7 [32000/60000 (53%)]	Loss: 0.017106	训练正确率: 98.66%	校验正确率: 97.88%
# (tensor(4894), 5000)
# 训练周期: 7 [38400/60000 (64%)]	Loss: 0.031133	训练正确率: 98.65%	校验正确率: 97.88%
# (tensor(4908), 5000)
# 训练周期: 7 [44800/60000 (75%)]	Loss: 0.042458	训练正确率: 98.65%	校验正确率: 98.16%
# (tensor(4903), 5000)
# 训练周期: 7 [51200/60000 (85%)]	Loss: 0.075126	训练正确率: 98.66%	校验正确率: 98.06%
# (tensor(4879), 5000)
# 训练周期: 7 [57600/60000 (96%)]	Loss: 0.023520	训练正确率: 98.65%	校验正确率: 97.58%
# (tensor(4895), 5000)
# 训练周期: 8 [0/60000 (0%)]	Loss: 0.047446	训练正确率: 96.88%	校验正确率: 97.90%
# (tensor(4906), 5000)
# 训练周期: 8 [6400/60000 (11%)]	Loss: 0.123058	训练正确率: 98.59%	校验正确率: 98.12%
# (tensor(4901), 5000)
# 训练周期: 8 [12800/60000 (21%)]	Loss: 0.020708	训练正确率: 98.64%	校验正确率: 98.02%
# (tensor(4903), 5000)
# 训练周期: 8 [19200/60000 (32%)]	Loss: 0.024432	训练正确率: 98.59%	校验正确率: 98.06%
# (tensor(4888), 5000)
# 训练周期: 8 [25600/60000 (43%)]	Loss: 0.113037	训练正确率: 98.61%	校验正确率: 97.76%
# (tensor(4910), 5000)
# 训练周期: 8 [32000/60000 (53%)]	Loss: 0.033835	训练正确率: 98.69%	校验正确率: 98.20%
# (tensor(4899), 5000)
# 训练周期: 8 [38400/60000 (64%)]	Loss: 0.007141	训练正确率: 98.67%	校验正确率: 97.98%
# (tensor(4910), 5000)
# 训练周期: 8 [44800/60000 (75%)]	Loss: 0.049667	训练正确率: 98.64%	校验正确率: 98.20%
# (tensor(4882), 5000)
# 训练周期: 8 [51200/60000 (85%)]	Loss: 0.052127	训练正确率: 98.64%	校验正确率: 97.64%
# (tensor(4900), 5000)
# 训练周期: 8 [57600/60000 (96%)]	Loss: 0.012406	训练正确率: 98.65%	校验正确率: 98.00%
# (tensor(4899), 5000)
# 训练周期: 9 [0/60000 (0%)]	Loss: 0.036055	训练正确率: 98.44%	校验正确率: 97.98%
# (tensor(4916), 5000)
# 训练周期: 9 [6400/60000 (11%)]	Loss: 0.001746	训练正确率: 98.65%	校验正确率: 98.32%
# (tensor(4905), 5000)
# 训练周期: 9 [12800/60000 (21%)]	Loss: 0.031082	训练正确率: 98.62%	校验正确率: 98.10%
# (tensor(4890), 5000)
# 训练周期: 9 [19200/60000 (32%)]	Loss: 0.159320	训练正确率: 98.72%	校验正确率: 97.80%
# (tensor(4885), 5000)
# 训练周期: 9 [25600/60000 (43%)]	Loss: 0.103247	训练正确率: 98.78%	校验正确率: 97.70%
# (tensor(4907), 5000)
# 训练周期: 9 [32000/60000 (53%)]	Loss: 0.012537	训练正确率: 98.75%	校验正确率: 98.14%
# (tensor(4901), 5000)
# 训练周期: 9 [38400/60000 (64%)]	Loss: 0.035215	训练正确率: 98.69%	校验正确率: 98.02%
# (tensor(4907), 5000)
# 训练周期: 9 [44800/60000 (75%)]	Loss: 0.041331	训练正确率: 98.69%	校验正确率: 98.14%
# (tensor(4900), 5000)
# 训练周期: 9 [51200/60000 (85%)]	Loss: 0.035397	训练正确率: 98.73%	校验正确率: 98.00%
# (tensor(4919), 5000)
# 训练周期: 9 [57600/60000 (96%)]	Loss: 0.001750	训练正确率: 98.71%	校验正确率: 98.38%
# (tensor(4906), 5000)
# 训练周期: 10 [0/60000 (0%)]	Loss: 0.095765	训练正确率: 98.44%	校验正确率: 98.12%
# (tensor(4904), 5000)
# 训练周期: 10 [6400/60000 (11%)]	Loss: 0.001601	训练正确率: 98.86%	校验正确率: 98.08%
# (tensor(4903), 5000)
# 训练周期: 10 [12800/60000 (21%)]	Loss: 0.009387	训练正确率: 98.87%	校验正确率: 98.06%
# (tensor(4914), 5000)
# 训练周期: 10 [19200/60000 (32%)]	Loss: 0.041185	训练正确率: 98.89%	校验正确率: 98.28%
# (tensor(4912), 5000)
# 训练周期: 10 [25600/60000 (43%)]	Loss: 0.005347	训练正确率: 98.85%	校验正确率: 98.24%
# (tensor(4898), 5000)
# 训练周期: 10 [32000/60000 (53%)]	Loss: 0.009709	训练正确率: 98.85%	校验正确率: 97.96%
# (tensor(4907), 5000)
# 训练周期: 10 [38400/60000 (64%)]	Loss: 0.068268	训练正确率: 98.80%	校验正确率: 98.14%
# (tensor(4912), 5000)
# 训练周期: 10 [44800/60000 (75%)]	Loss: 0.002555	训练正确率: 98.76%	校验正确率: 98.24%
# (tensor(4897), 5000)
# 训练周期: 10 [51200/60000 (85%)]	Loss: 0.072833	训练正确率: 98.77%	校验正确率: 97.94%
# (tensor(4907), 5000)
# 训练周期: 10 [57600/60000 (96%)]	Loss: 0.013924	训练正确率: 98.75%	校验正确率: 98.14%
# (tensor(4905), 5000)
# 训练周期: 11 [0/60000 (0%)]	Loss: 0.041375	训练正确率: 96.88%	校验正确率: 98.10%
# (tensor(4897), 5000)
# 训练周期: 11 [6400/60000 (11%)]	Loss: 0.013927	训练正确率: 98.93%	校验正确率: 97.94%
# (tensor(4898), 5000)
# 训练周期: 11 [12800/60000 (21%)]	Loss: 0.053231	训练正确率: 98.87%	校验正确率: 97.96%
# (tensor(4898), 5000)
# 训练周期: 11 [19200/60000 (32%)]	Loss: 0.033448	训练正确率: 98.85%	校验正确率: 97.96%
# (tensor(4898), 5000)
# 训练周期: 11 [25600/60000 (43%)]	Loss: 0.002723	训练正确率: 98.85%	校验正确率: 97.96%
# (tensor(4911), 5000)
# 训练周期: 11 [32000/60000 (53%)]	Loss: 0.030164	训练正确率: 98.80%	校验正确率: 98.22%
# (tensor(4904), 5000)
# 训练周期: 11 [38400/60000 (64%)]	Loss: 0.012914	训练正确率: 98.80%	校验正确率: 98.08%
# (tensor(4889), 5000)
# 训练周期: 11 [44800/60000 (75%)]	Loss: 0.040750	训练正确率: 98.79%	校验正确率: 97.78%
# (tensor(4891), 5000)
# 训练周期: 11 [51200/60000 (85%)]	Loss: 0.191705	训练正确率: 98.77%	校验正确率: 97.82%
# (tensor(4900), 5000)
# 训练周期: 11 [57600/60000 (96%)]	Loss: 0.038749	训练正确率: 98.76%	校验正确率: 98.00%
# (tensor(4890), 5000)
# 训练周期: 12 [0/60000 (0%)]	Loss: 0.014477	训练正确率: 100.00%	校验正确率: 97.80%
# (tensor(4913), 5000)
# 训练周期: 12 [6400/60000 (11%)]	Loss: 0.004922	训练正确率: 98.79%	校验正确率: 98.26%
# (tensor(4906), 5000)
# 训练周期: 12 [12800/60000 (21%)]	Loss: 0.017247	训练正确率: 98.80%	校验正确率: 98.12%
# (tensor(4899), 5000)
# 训练周期: 12 [19200/60000 (32%)]	Loss: 0.000727	训练正确率: 98.78%	校验正确率: 97.98%
# (tensor(4908), 5000)
# 训练周期: 12 [25600/60000 (43%)]	Loss: 0.025695	训练正确率: 98.78%	校验正确率: 98.16%
# (tensor(4906), 5000)
# 训练周期: 12 [32000/60000 (53%)]	Loss: 0.006435	训练正确率: 98.81%	校验正确率: 98.12%
# (tensor(4885), 5000)
# 训练周期: 12 [38400/60000 (64%)]	Loss: 0.012244	训练正确率: 98.82%	校验正确率: 97.70%
# (tensor(4916), 5000)
# 训练周期: 12 [44800/60000 (75%)]	Loss: 0.071641	训练正确率: 98.80%	校验正确率: 98.32%
# (tensor(4912), 5000)
# 训练周期: 12 [51200/60000 (85%)]	Loss: 0.003701	训练正确率: 98.79%	校验正确率: 98.24%
# (tensor(4890), 5000)
# 训练周期: 12 [57600/60000 (96%)]	Loss: 0.102955	训练正确率: 98.78%	校验正确率: 97.80%
# (tensor(4900), 5000)
# 训练周期: 13 [0/60000 (0%)]	Loss: 0.002461	训练正确率: 100.00%	校验正确率: 98.00%
# (tensor(4912), 5000)
# 训练周期: 13 [6400/60000 (11%)]	Loss: 0.006429	训练正确率: 99.06%	校验正确率: 98.24%
# (tensor(4902), 5000)
# 训练周期: 13 [12800/60000 (21%)]	Loss: 0.013473	训练正确率: 99.00%	校验正确率: 98.04%
# (tensor(4901), 5000)
# 训练周期: 13 [19200/60000 (32%)]	Loss: 0.001559	训练正确率: 98.84%	校验正确率: 98.02%
# (tensor(4891), 5000)
# 训练周期: 13 [25600/60000 (43%)]	Loss: 0.071884	训练正确率: 98.88%	校验正确率: 97.82%
# (tensor(4908), 5000)
# 训练周期: 13 [32000/60000 (53%)]	Loss: 0.065684	训练正确率: 98.80%	校验正确率: 98.16%
# (tensor(4902), 5000)
# 训练周期: 13 [38400/60000 (64%)]	Loss: 0.017018	训练正确率: 98.84%	校验正确率: 98.04%
# (tensor(4899), 5000)
# 训练周期: 13 [44800/60000 (75%)]	Loss: 0.095551	训练正确率: 98.83%	校验正确率: 97.98%
# (tensor(4889), 5000)
# 训练周期: 13 [51200/60000 (85%)]	Loss: 0.040354	训练正确率: 98.82%	校验正确率: 97.78%
# (tensor(4897), 5000)
# 训练周期: 13 [57600/60000 (96%)]	Loss: 0.064325	训练正确率: 98.79%	校验正确率: 97.94%
# (tensor(4891), 5000)
# 训练周期: 14 [0/60000 (0%)]	Loss: 0.049800	训练正确率: 96.88%	校验正确率: 97.82%
# (tensor(4905), 5000)
# 训练周期: 14 [6400/60000 (11%)]	Loss: 0.002814	训练正确率: 98.96%	校验正确率: 98.10%
# (tensor(4903), 5000)
# 训练周期: 14 [12800/60000 (21%)]	Loss: 0.039304	训练正确率: 98.90%	校验正确率: 98.06%
# (tensor(4894), 5000)
# 训练周期: 14 [19200/60000 (32%)]	Loss: 0.000864	训练正确率: 98.95%	校验正确率: 97.88%
# (tensor(4909), 5000)
# 训练周期: 14 [25600/60000 (43%)]	Loss: 0.292717	训练正确率: 98.90%	校验正确率: 98.18%
# (tensor(4900), 5000)
# 训练周期: 14 [32000/60000 (53%)]	Loss: 0.002573	训练正确率: 98.86%	校验正确率: 98.00%
# (tensor(4887), 5000)
# 训练周期: 14 [38400/60000 (64%)]	Loss: 0.031421	训练正确率: 98.88%	校验正确率: 97.74%
# (tensor(4889), 5000)
# 训练周期: 14 [44800/60000 (75%)]	Loss: 0.008651	训练正确率: 98.86%	校验正确率: 97.78%
# (tensor(4910), 5000)
# 训练周期: 14 [51200/60000 (85%)]	Loss: 0.048696	训练正确率: 98.83%	校验正确率: 98.20%
# (tensor(4902), 5000)
# 训练周期: 14 [57600/60000 (96%)]	Loss: 0.087363	训练正确率: 98.80%	校验正确率: 98.04%
# (tensor(4899), 5000)
# 训练周期: 15 [0/60000 (0%)]	Loss: 0.050810	训练正确率: 96.88%	校验正确率: 97.98%
# (tensor(4906), 5000)
# 训练周期: 15 [6400/60000 (11%)]	Loss: 0.058667	训练正确率: 98.82%	校验正确率: 98.12%
# (tensor(4902), 5000)
# 训练周期: 15 [12800/60000 (21%)]	Loss: 0.000600	训练正确率: 98.85%	校验正确率: 98.04%
# (tensor(4900), 5000)
# 训练周期: 15 [19200/60000 (32%)]	Loss: 0.006845	训练正确率: 98.86%	校验正确率: 98.00%
# (tensor(4903), 5000)
# 训练周期: 15 [25600/60000 (43%)]	Loss: 0.035195	训练正确率: 98.85%	校验正确率: 98.06%
# (tensor(4889), 5000)
# 训练周期: 15 [32000/60000 (53%)]	Loss: 0.121815	训练正确率: 98.84%	校验正确率: 97.78%
# (tensor(4900), 5000)
# 训练周期: 15 [38400/60000 (64%)]	Loss: 0.099821	训练正确率: 98.81%	校验正确率: 98.00%
# (tensor(4902), 5000)
# 训练周期: 15 [44800/60000 (75%)]	Loss: 0.001551	训练正确率: 98.82%	校验正确率: 98.04%
# (tensor(4896), 5000)
# 训练周期: 15 [51200/60000 (85%)]	Loss: 0.011427	训练正确率: 98.83%	校验正确率: 97.92%
# (tensor(4898), 5000)
# 训练周期: 15 [57600/60000 (96%)]	Loss: 0.008596	训练正确率: 98.81%	校验正确率: 97.96%
# (tensor(4904), 5000)
# 训练周期: 16 [0/60000 (0%)]	Loss: 0.045207	训练正确率: 98.44%	校验正确率: 98.08%
# (tensor(4901), 5000)
# 训练周期: 16 [6400/60000 (11%)]	Loss: 0.009193	训练正确率: 98.86%	校验正确率: 98.02%
# (tensor(4888), 5000)
# 训练周期: 16 [12800/60000 (21%)]	Loss: 0.002672	训练正确率: 98.83%	校验正确率: 97.76%
# (tensor(4893), 5000)
# 训练周期: 16 [19200/60000 (32%)]	Loss: 0.084836	训练正确率: 98.81%	校验正确率: 97.86%
# (tensor(4899), 5000)
# 训练周期: 16 [25600/60000 (43%)]	Loss: 0.029384	训练正确率: 98.80%	校验正确率: 97.98%
# (tensor(4896), 5000)
# 训练周期: 16 [32000/60000 (53%)]	Loss: 0.049391	训练正确率: 98.84%	校验正确率: 97.92%
# (tensor(4889), 5000)
# 训练周期: 16 [38400/60000 (64%)]	Loss: 0.019829	训练正确率: 98.87%	校验正确率: 97.78%
# (tensor(4904), 5000)
# 训练周期: 16 [44800/60000 (75%)]	Loss: 0.030712	训练正确率: 98.86%	校验正确率: 98.08%
# (tensor(4898), 5000)
# 训练周期: 16 [51200/60000 (85%)]	Loss: 0.007017	训练正确率: 98.84%	校验正确率: 97.96%
# (tensor(4906), 5000)
# 训练周期: 16 [57600/60000 (96%)]	Loss: 0.079296	训练正确率: 98.82%	校验正确率: 98.12%
# (tensor(4900), 5000)
# 训练周期: 17 [0/60000 (0%)]	Loss: 0.049443	训练正确率: 98.44%	校验正确率: 98.00%
# (tensor(4899), 5000)
# 训练周期: 17 [6400/60000 (11%)]	Loss: 0.034549	训练正确率: 99.06%	校验正确率: 97.98%
# (tensor(4906), 5000)
# 训练周期: 17 [12800/60000 (21%)]	Loss: 0.037002	训练正确率: 98.99%	校验正确率: 98.12%
# (tensor(4910), 5000)
# 训练周期: 17 [19200/60000 (32%)]	Loss: 0.018544	训练正确率: 98.93%	校验正确率: 98.20%
# (tensor(4909), 5000)
# 训练周期: 17 [25600/60000 (43%)]	Loss: 0.005667	训练正确率: 98.92%	校验正确率: 98.18%
# (tensor(4903), 5000)
# 训练周期: 17 [32000/60000 (53%)]	Loss: 0.000997	训练正确率: 98.96%	校验正确率: 98.06%
# (tensor(4910), 5000)
# 训练周期: 17 [38400/60000 (64%)]	Loss: 0.009000	训练正确率: 98.94%	校验正确率: 98.20%
# (tensor(4911), 5000)
# 训练周期: 17 [44800/60000 (75%)]	Loss: 0.077446	训练正确率: 98.89%	校验正确率: 98.22%
# (tensor(4897), 5000)
# 训练周期: 17 [51200/60000 (85%)]	Loss: 0.072764	训练正确率: 98.88%	校验正确率: 97.94%
# (tensor(4907), 5000)
# 训练周期: 17 [57600/60000 (96%)]	Loss: 0.001066	训练正确率: 98.89%	校验正确率: 98.14%
# (tensor(4905), 5000)
# 训练周期: 18 [0/60000 (0%)]	Loss: 0.005974	训练正确率: 100.00%	校验正确率: 98.10%
# (tensor(4899), 5000)
# 训练周期: 18 [6400/60000 (11%)]	Loss: 0.001237	训练正确率: 99.09%	校验正确率: 97.98%
# (tensor(4898), 5000)
# 训练周期: 18 [12800/60000 (21%)]	Loss: 0.167029	训练正确率: 99.03%	校验正确率: 97.96%
# (tensor(4917), 5000)
# 训练周期: 18 [19200/60000 (32%)]	Loss: 0.009897	训练正确率: 98.99%	校验正确率: 98.34%
# (tensor(4890), 5000)
# 训练周期: 18 [25600/60000 (43%)]	Loss: 0.001207	训练正确率: 98.95%	校验正确率: 97.80%
# (tensor(4904), 5000)
# 训练周期: 18 [32000/60000 (53%)]	Loss: 0.019791	训练正确率: 98.93%	校验正确率: 98.08%
# (tensor(4910), 5000)
# 训练周期: 18 [38400/60000 (64%)]	Loss: 0.029535	训练正确率: 98.93%	校验正确率: 98.20%
# (tensor(4897), 5000)
# 训练周期: 18 [44800/60000 (75%)]	Loss: 0.002147	训练正确率: 98.89%	校验正确率: 97.94%
# (tensor(4914), 5000)
# 训练周期: 18 [51200/60000 (85%)]	Loss: 0.056828	训练正确率: 98.91%	校验正确率: 98.28%
# (tensor(4893), 5000)
# 训练周期: 18 [57600/60000 (96%)]	Loss: 0.002979	训练正确率: 98.90%	校验正确率: 97.86%
# (tensor(4898), 5000)
# 训练周期: 19 [0/60000 (0%)]	Loss: 0.003606	训练正确率: 100.00%	校验正确率: 97.96%
# (tensor(4904), 5000)
# 训练周期: 19 [6400/60000 (11%)]	Loss: 0.016321	训练正确率: 98.99%	校验正确率: 98.08%
# (tensor(4892), 5000)
# 训练周期: 19 [12800/60000 (21%)]	Loss: 0.074879	训练正确率: 98.97%	校验正确率: 97.84%
# (tensor(4903), 5000)
# 训练周期: 19 [19200/60000 (32%)]	Loss: 0.022574	训练正确率: 98.98%	校验正确率: 98.06%
# (tensor(4903), 5000)
# 训练周期: 19 [25600/60000 (43%)]	Loss: 0.014311	训练正确率: 98.98%	校验正确率: 98.06%
# (tensor(4905), 5000)
# 训练周期: 19 [32000/60000 (53%)]	Loss: 0.017336	训练正确率: 98.93%	校验正确率: 98.10%
# (tensor(4901), 5000)
# 训练周期: 19 [38400/60000 (64%)]	Loss: 0.126206	训练正确率: 98.90%	校验正确率: 98.02%
# (tensor(4902), 5000)
# 训练周期: 19 [44800/60000 (75%)]	Loss: 0.009270	训练正确率: 98.92%	校验正确率: 98.04%
# (tensor(4905), 5000)
# 训练周期: 19 [51200/60000 (85%)]	Loss: 0.057426	训练正确率: 98.92%	校验正确率: 98.10%
# (tensor(4905), 5000)
# 训练周期: 19 [57600/60000 (96%)]	Loss: 0.017448	训练正确率: 98.89%	校验正确率: 98.10%
# Text(0, 0.5, 'Error Rate')
