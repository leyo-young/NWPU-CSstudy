# %%
import cv2
import numpy as np

# 读入图像并显示
o1= cv2.imread("/home/retoo/Desktop/实验/数据集/4 数字图像处理/9-1.png")
o2= cv2.imread("/home/retoo/Desktop/实验/数据集/4 数字图像处理/9-2.png")
o3= cv2.imread("/home/retoo/Desktop/实验/数据集/4 数字图像处理/9-3.png")
cv2.imshow("original1",o1)
cv2.imshow("original2",o2)
cv2.imshow("original3",o3)

# 将图像转化二值化灰度图像
gray1= cv2.cvtColor(o1,cv2.COLOR_BGR2GRAY)
gray2= cv2.cvtColor(o2,cv2.COLOR_BGR2GRAY)
gray3= cv2.cvtColor(o3,cv2.COLOR_BGR2GRAY)

# 将图像进行阈值处理
ret, binary1 = cv2.threshold(gray1,127,255,cv2.THRESH_BINARY)
ret, binary2 = cv2.threshold(gray2,127,255,cv2.THRESH_BINARY)
ret, binary3 = cv2.threshold(gray3,127,255,cv2.THRESH_BINARY)

# 寻找图像的轮廓
contours1,hierarchy = cv2.findContours(binary1,cv2.RETR_LIST,cv2.CHAIN_APPROX_SIMPLE)
contours2,hierarchy = cv2.findContours(binary2,cv2.RETR_LIST,cv2.CHAIN_APPROX_SIMPLE)
contours3,hierarchy = cv2.findContours(binary3,cv2.RETR_LIST,cv2.CHAIN_APPROX_SIMPLE)

# 比较3幅图像与第1幅图像之间的Hu矩值
cnt1 = contours1[0]
cnt2 = contours2[0]
cnt3 = contours3[0]
ret0 = cv2.matchShapes(cnt1,cnt1,1,0.0)
ret1 = cv2.matchShapes(cnt1,cnt2,1,0.0)
ret2 = cv2.matchShapes(cnt1,cnt3,1,0.0)

# 寻找相似图像，构造最小包围矩形框来选取相似图像
a=ret1-ret0
if(a<1):
 rect= cv2.minAreaRect(contours2[0])
 points= cv2.boxPoints(rect)
 points = np.int0(points)
 image=cv2.drawContours(o2,[points],0,(255,255,255),2)
else:
    rect = cv2.minAreaRect(contours3[0])
    points = cv2.boxPoints(rect)
    points = np.int0(points)
    image = cv2.drawContours(o3, [points], 0, (255, 255, 255), 2)

# 显示Hu矩值和相似图像
print("相同图像的matchShape=",ret0)
print("相似图像的matchShape=",ret1)
print("不相似图像的matchShape=",ret2)
cv2.imshow("result",o2)
cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# 相同图像的matchShape= 0.0
# 相似图像的matchShape= 0.17228663549035467
# 不相似图像的matchShape= 3.3331732076848914
