# %%
# 导入库函数
import cv2
import numpy as np
# %matplotlib inline
from matplotlib import pyplot as plt

# 读图像
img = cv2.imread("/home/retoo/Desktop/实验/数据集/4 数字图像处理/5.jpg",0)

# 傅里叶变换，将图像从空间域转换至频域
dft = cv2.dft(np.float32(img),flags=cv2.DFT_COMPLEX_OUTPUT)

# 将图像中的低频部分移动到图像的中心
dftShift = np.fft.fftshift(dft)

# 设置低通滤波器
rows, cols = img.shape
crow,ccol = int(rows/2), int(cols/2)
mask = np.zeros((rows,cols,2),np.uint8)
mask[crow-30:crow+30, ccol-30:ccol+30] = 1

# 低通滤波，提取低频成分
fShift = dftShift*mask

# 傅里叶逆变换
# 将图像的低频和高频部分移动到图像原来的位置
ishift = np.fft.ifftshift(fShift)
# 傅里叶逆变换，将图像从频域转换至空间域
iTmg = cv2.idft(ishift)
# 将实部和虚部投影到空间域
iTmg= cv2.magnitude(iTmg[:,:,0],iTmg[:,:,1])

# 显示图像
plt.subplot(121),plt.imshow(img, cmap='gray')
plt.title('original'),plt.axis('off') #显示原图像的灰度图像
plt.subplot(122),plt.imshow(iTmg,cmap = 'gray') # 显示低通滤波后图像
plt.title('inverse'),plt.axis('off')
plt.show()
